# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
avg_bill = tips.groupby('day', as_index=False)['total_bill'].mean()

# %%
day_order = ['Thur', 'Fri', 'Sat', 'Sun']
avg_bill['day'] = pd.Categorical(avg_bill['day'], categories=day_order, ordered=True)
avg_bill = avg_bill.sort_values('day')

# %%
plt.figure(figsize=(8, 6))

# %%
x_positions = range(len(avg_bill))

# %%
plt.bar(x_positions, avg_bill['total_bill'], color='skyblue', edgecolor='black', width=0.6)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xticks(x_positions, avg_bill['day'])
# Out:
# ([<matplotlib.axis.XTick at 0x692cd450>,
# ...
#  [Text(0, 0, 'Thur'), Text(1, 0, 'Fri'), Text(2, 0, 'Sat'), Text(3, 0, 'Sun')])

# %%
plt.xlabel('Day of Week', fontsize=12)
plt.ylabel('Average Total Bill ($)', fontsize=12)
plt.title('Average Total Bill by Day (MatplotLib)', fontsize=14, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="whitegrid", rc = {"figure.figsize": (5, 5)})
sns.set_palette('hls', 12)

# %%
sns.barplot(data=df, # df name
    x='day', # x -axis column
    y='total_bill', # y -axis column
    estimator='mean', # Apply function to y-axis column
    hue='day', # group designation
    legend=None # Do not display 
)
plt.show()

# %%
pivot_df = tips.pivot_table(index='day', columns='sex', values='total_bill', aggfunc='mean')
pivot_df = pivot_df.reindex(['Thur', 'Fri', 'Sat', 'Sun'])

# %%
x = np.arrange(len(pivot_df.index))
width = 0.35
fig, ax = plt.subplots(figsize=(10, 6))

# %%
bars1 = ax.bar(x - width/2, pivot_df['Male'], width, label='Male', color='#FF6B6B')
bars2 = ax.bar(x - width/2, pivot_df['Female'], width, label='Female', color='#4ECDC4')

# %%
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Average Total Bill ($)')
ax.set

# %%
sns.barplot(data=df, # df name
    x='day', # x -axis column
    y='total_bill', # y -axis column
    estimator='mean', # Apply function to y-axis column
    hue='sex', # Grouping criteria for y-axis values
    ci=None # Delete error line
)
plt.show()
# Out:
# C:\Users\superuser\AppData\Local\Temp\ipykernel_5232\4053221394.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, # df name

# %%
# cumulative bar graph ni part
df2 = df.pivot_table(index = 'day', # Column to be inserted into the row position
    columns = 'sex', # Columns to be placed in the column positions
    values = 'total_bill', # Column to use as data
    aggfunc = 'mean' # data aggregation function
    )
df2

df2.plot.bar(stacked=True)
plt.subplots_adjust (bottom=0.2)
plt.show()
