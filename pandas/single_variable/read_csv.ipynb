# %%
import pandas as pd

df = pd.read_csv('../../spreadsheets/iris.csv')
df # Check contents

# %%
df.info # Genral info about the dataframe object
df.shape # Array shape
df.shape[0] # number of rows
df.shape[1]

# %%
df.dtypes # Data type for each column. Default type of string column is 'object'
df['Species'] = df['species'].astype('category')
df['Species']
df['Species'].unique()

# %%
df.loc[[2, 10, 34], ['petal_width', 'species']]
df.loc[0:3], ['petal_length', 'species']

# %%
df2 = df.loc[:, df.columns != "species"]
df2

# %%
df.describe()

# %%
df3 = df.copy()
df3.iloc[1,2] = 5.5 
df3.loc[1,'petal_Length'] = 1.1

# %%
df3_list = df3.petal_Length.to_list()
df3.shape[0]

# %%
# add new row @ tail

new_idx = df3.shape[0]
df4 = df3.loc[new_idx] = [1.1, 4.5, 3.4, 2.2, 'setosa']
df4
