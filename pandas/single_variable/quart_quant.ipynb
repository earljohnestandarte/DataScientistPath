# %%
import pandas as pd
import numpy as np

# %%
mydata = [60, 62, 64, 65, 68, 69, 120]
mydata = pd.Series(mydata)

# %%
mydata.quantile(0.25)
# Out:
# np.float64(63.0)

# %%
mydata.quantile(0.5)
# Out:
# np.float64(65.0)

# %%
mydata.quantile(0.75)
# Out:
# np.float64(68.5)

# %%
mydata.quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    63.0
# 0.50    65.0
# 0.75    68.5
# dtype: float64

# %%
mydata.quantile(np.arange(0, 1, 0.1))
mydata.describe()
# Out:
# count      7.000000
# mean      72.571429
# std       21.149130
# min       60.000000
# 25%       63.000000
# 50%       65.000000
# 75%       68.500000
# max      120.000000
# dtype: float64

# %%
mydata.var()
mydata.std()
# Out:
# np.float64(21.149130343484913)
