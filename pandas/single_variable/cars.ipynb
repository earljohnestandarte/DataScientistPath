# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cars = pd.read_csv('../../spreadsheets/cars.csv')
speed = cars['top_speed_kmh']
speed
# Out:
# 0     240
# 1     190
# 2     190
# 3     250
# 4     235
# 5     340
# 6     340
# 7     191
# 8     191
# 9     145
# 10    145
# 11    173
# 12    210
# 13    197
# 14    161
# 15    159
# 16    350
# 17    305
# 18    250
# 19    200
# 20    200
# 21    140
# 22    140
# 23    240
# 24    250
# 25    180
# 26    300
# 27    315
# 28    188
# 29    217
# 30    241
# 31    190
# 32    190
# 33    225
# 34    163
# 35    180
# 36    180
# Name: top_speed_kmh, dtype: int64

# %%
speed.plot.hist(bins=150)
plt.show()

# %%
speed.plot.box(title='Top Speed kmh')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
