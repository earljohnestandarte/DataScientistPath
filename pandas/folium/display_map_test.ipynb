# %%
import folium
import os

import displayMap as dm

# %%
loc = [9.31184273992069, 123.30723539459946]
map = folium.Map(location=loc, zoom_start = 16)
folium.Marker(location=loc, # Marker display 
    icon= folium.Icon(color='red', icon ='star')).add_to(map)
dm.showMap(map)
