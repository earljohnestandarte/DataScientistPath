# %%
import pandas as pd

# %%
score = pd.Series([30, 20, 40, pd.NA, 30, pd.NA])
score
# Out:
# 0      30
# 1      20
# 2      40
# 3    <NA>
# 4      30
# 5    <NA>
# dtype: object

# %%
score.sum()
# Out:
# 120

# %%
score.mean()
# Out:
# np.float64(30.0)

# %%
score + 5
# Out:
# 0      35
# 1      25
# 2      45
# 3    <NA>
# 4      35
# 5    <NA>
# dtype: object

# %%
pd.isna(score)
pd.isna(score).sum()
# Out:
# np.int64(2)

# %%
score.size
# Out:
# 6

# %%
score.count()
# Out:
# np.int64(4)

# %%
pd.notna(score)
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
pd.notna(score).sum()
# Out:
# np.int64(4)

# %%
score = score.dropna()
score
# Out:
# 0    30
# 1    20
# 2    40
# 4    30
# dtype: object

# %%
score = score.reset_index(drop=True)
score
# Out:
# 0    30
# 1    20
# 2    40
# 3    30
# dtype: object
