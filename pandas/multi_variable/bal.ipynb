# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
beers = [5, 2, 9, 8, 3, 7, 3, 5, 3, 5]
bal = [0.1,0.03,0.19,0.12,0.04,0.0095,0.07,0.06,0.02,0.05]

# %%
dict = {'beers': beers, 'bal': bal}
df = pd.DataFrame(dict)
df

# %%
df.plot.scatter(
    x='beers',
    y='bal',
    title='Beers~Blood Alcohol Level'
)
# Out:
# <Axes: title={'center': 'Beers~Blood Alcohol Level'}, xlabel='beers', ylabel='bal'>

# %%
m, b = np.polyfit(beers, bal, 1)
plt.plot(beers, m * np.array(beers) + b)
plt.show()

# %%
df['beers'].corr(df['bal'])
# Out:
# np.float64(0.6797024899347416)

# %%
df2 = pd.read_csv('../../spreadsheets/iris.csv')
df2.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='str')

# %%
df2 = df2.loc[:, ~df2.columns.isin(['species'])]
df2.columns
df2.corr(method='pearson')
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.072112      0.717624     0.654960
# sepal_width      -0.072112     1.000000     -0.182391    -0.146988
# petal_length      0.717624    -0.182391      1.000000     0.803014
# petal_width       0.654960    -0.146988      0.803014     1.000000

# %%
df2.corr(method='kendall')
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.072112      0.717624     0.654960
# sepal_width      -0.072112     1.000000     -0.182391    -0.146988
# petal_length      0.717624    -0.182391      1.000000     0.803014
# petal_width       0.654960    -0.146988      0.803014     1.000000

# %%
df2.corr(method='spearman')
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.159457      0.881386     0.834421
# sepal_width      -0.159457     1.000000     -0.303421    -0.277511
# petal_length      0.881386    -0.303421      1.000000     0.936003
# petal_width       0.834421    -0.277511      0.936003     1.000000
